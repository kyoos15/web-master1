# %% [markdown]
# <a href="https://colab.research.google.com/github/kyoos15/web-master1/blob/main/Contradiction_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd

splits = {'train': 'train.csv', 'test': 'test1.csv'}
df = pd.read_csv("hf://datasets/chitra/contradictionNLI/" + splits["train"])
df
# Out:
#                                                 premise  \
# 0     and these comments were considered in formulat...
# 1     These are issues that we wrestle with in pract...
# 2     you know they can't really defend themselves l...
# 3                 From Cockpit Country to St. Ann's Bay
# 4     Look, it's your skin, but you're going to be i...
# ...                                                 ...
# 5869   "The summons was only for Dave Hanson," Ser P...
# 5870  and these comments were considered in formulat...
# 5871       There are two challengers to these top dogs.
# 5872  Even after we hire good people, we need to tak...
# 5873  Clinton used a floor mop to clean up the dirt ...
#
#                                              hypothesis  label
# 0     The rules developed in the interim were put to...      0
# 1     Practice groups are not permitted to work on t...      2
# 2     They can't defend themselves because of their ...      0
# ...
